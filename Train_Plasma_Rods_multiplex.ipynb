# %%
import numpy as np
import autograd.numpy as npa
import matplotlib as mpl
mpl.rcParams['figure.dpi']=100
import matplotlib.pylab as plt
from autograd.scipy.signal import convolve as conv
from skimage.draw import circle
import ceviche
from ceviche import fdfd_ez, jacobian, fdfd_hz
from ceviche.optimizers import adam_optimize
from ceviche.modes import insert_mode
import collections
from make_gif import make_gif
# Create a container for our slice coords to be used for sources and probes
Slice = collections.namedtuple('Slice', 'x y')

# %%
# The two angular frequencies
omega1=2*np.pi*200e12
omega2=2*np.pi*230e12
# Spatial resolution in meters
dl=40e-9
# Number of pixels in x-direction
Nx=240
# Number of pixels in y-direction
Ny=240
# Number of pixels in the PMLs in each direction
Npml=40
# Minimum value of the relative permittivity
epsr_train_min=-6.0
epsr_train_max=1.0
# Maximum value of the relative permittivity
epsr_design=1.0
epsr_bckgd=12.0

#------------------- Domain Constants -------------------#
# Space between the PMLs and the design region (in pixels)
space=20
# Width of the waveguide (in pixels)
wg_width=24
# Length in pixels of the source/probe slices on each side of the center point
space_slice=16
# Number of dots in a row/column
num_dots=6
# Radius of dots
circle_rad=int((Nx-2*(Npml+space))/(2*num_dots))
# Lattice constant
ra=0.6

#---------------- Optimization Constants ----------------#
# Number of epochs in the optimization 
Nsteps=500
# Step size for the Adam optimizer
step_size=5e-4

#------------------ Graphing Constants ------------------#
Emax=0
emin=-6
emax=1

# %%
print(omega2*2*circle_rad*dl/299792458)
# Out:
# 3.856354840391094

# %%
# set the colormap and centre the colorbar
class MidpointNormalize(mpl.colors.Normalize):
    """
    Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)

    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        mpl.colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))
    
def real(val, outline=None, ax=None, cbar=False, cmap='RdBu', outline_alpha=0.5, vmin=None, vmax=None):
    """Plots the real part of 'val', optionally overlaying an outline of 'outline'
    """
    if ax is None:
        fig, ax = plt.subplots(1, 1, constrained_layout=True)
    
    if vmin is None:
        vmax = np.real(val).max()
        vmin = np.real(val).min()
    h = ax.imshow(np.real(val.T), cmap=cmap, origin='lower left', clim=(vmin, vmax), \
                  norm=MidpointNormalize(midpoint=0,vmin=vmin,vmax=vmax))
    
    if outline is not None:
        ax.contour(outline.T, 0, colors='k', alpha=outline_alpha)

    if cbar:
        cbar = plt.colorbar(h, ax=ax)
        cbar.set_ticks([-6, 0, 1])
        cbar.set_ticklabels(['-6', '0', '1'])
        cbar.ax.set_ylabel('Relative Permittivity')
    
    return ax

def abslt(val, outline=None, ax=None, cbar=False, cmap='magma', outline_alpha=0.5, outline_val=None, vmax=None):
    """Plots the absolute value of 'val', optionally overlaying an outline of 'outline'
    """
    if ax is None:
        fig, ax = plt.subplots(1, 1, constrained_layout=True)      
    
    if vmax is None:
        vmax = np.abs(val).max()
    h = ax.imshow(np.abs(val.T), cmap=cmap, origin='lower left', vmin=0, vmax=vmax)
    
    if outline_val is None and outline is not None: outline_val = 0.5*(outline.min()+outline.max())
    if outline is not None:
        ax.contour(outline.T, [outline_val], colors='w', alpha=outline_alpha)

    if cbar:
        cbar = plt.colorbar(h, ax=ax)
        cbar.set_ticks([])
        cbar.ax.set_ylabel('Electric Field Strength')
    
    return ax

# %%
def viz_sim(epsr, source1, source2, slices=[], log=0):
    """Solve and visualize a simulation with permittivity 'epsr'
    """
    global emin, emax, Emax
    
    simulation1 = fdfd_hz(omega1, dl, epsr, [Npml, Npml])
    Ex1, _, _ = simulation1.solve(source1)
    simulation2 = fdfd_hz(omega2, dl, epsr, [Npml, Npml])
    Ex2, _, _ = simulation2.solve(source2)
    
    epsr_graph = np.array(epsr, copy=True)
    epsr_graph[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 0
    
    fig, axs = plt.subplots(1, 3, constrained_layout=True, figsize=(9,3))
    abslt(Ex1, outline=epsr_graph, ax=axs[0], cbar=False)
    abslt(Ex2, outline=epsr_graph, ax=axs[1], cbar=True)
    real(epsr, ax=axs[2], cmap='RdGy', cbar=True, vmin=emin, vmax=emax)
    for sl in slices:
        for ax in axs:
            try:
                ax.plot(sl.x*np.ones(len(sl.y)), sl.y, 'w-', alpha=0.5)
            except:
                ax.plot(sl.x, sl.y*np.ones(len(sl.x)), 'w-', alpha=0.5)
    axs[0].set_title('$\lambda_1$ = %.2f $\mu$m' % (299792458/(omega1/2/np.pi)/1e-6))
    axs[1].set_title('$\lambda_2$ = %.2f $\mu$m' % (299792458/(omega2/2/np.pi)/1e-6))
        
    if log:
        Estack = np.dstack((Ex1, Ex2))        
        if np.abs(Estack).max() > Emax:
            Emax = np.abs(Estack).max()
        np.savetxt('multiplex/tm/Ex1_%03d.csv' % log, np.abs(Ex1), delimiter=',')
        np.savetxt('multiplex/tm/Ex2_%03d.csv' % log, np.abs(Ex2), delimiter=',')
        
        if epsr.min() < emin:
            emin=epsr.min()
        if epsr.max() > emax:
            emax=epsr.max()
        np.savetxt('multiplex/tm/epsr_%03d.csv' % log, epsr, delimiter=',')
    
    return (simulation1, simulation2, axs, fig)

def mask_combine_rho(rods, bg_rho, design_region):
    """Utility function for combining the design region rho and the background rho
    """
    train = (epsr_train_max-epsr_train_min)*rods*(rods!=0).astype(np.float) + epsr_train_min*(rods!=0).astype(np.float)
    design = epsr_design*design_region*(rods==0).astype(np.float)
    bckgd = epsr_bckgd*bg_rho*(design_region==0).astype(np.float)
    return train + design + bckgd

def scale_epsrs(epsrs, rods):
    epsrs = epsrs.flatten()
    epsrs = npa.arctan(epsrs) / np.pi + 0.5 
    rho = np.zeros(rods[0].shape)
    for i in range(len(epsrs)):
        rho += epsrs[i]*rods[i]
    return rho

def epsr_parameterization(epsrs, bg_rho, design_region, rods):
    """Defines the parameterization steps for constructing rho
    """
    rods = scale_epsrs(epsrs, rods)
    return mask_combine_rho(rods, bg_rho, design_region)

# %%
def init_design(epsrs, Nx=Nx, Ny=Ny, Npml=Npml, space=space, num_dots=num_dots, circle_rad=circle_rad, ra=ra):
    # Selector for each plasma rod
    rods = [np.zeros((Nx, Ny)) for i in range(num_dots**2)]
    # Selector for entire design region
    design_region = np.zeros((Nx, Ny))
    design_region[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 1
    
    # Initialize selector for circular plasma rods
    center_x = Npml+space+circle_rad
    for i in range(num_dots):
        center_y = Npml+space+circle_rad
        for j in range(num_dots):
            r, c = circle(center_x, center_y, circle_rad*ra)
            rods[j + i*num_dots][r, c] = 1
            center_y = center_y + 2*circle_rad
        center_x = center_x + 2*circle_rad
        
    return rods, design_region
    
def init_guides(Nx=Nx, Ny=Ny, Npml=Npml, space=space, wg_width=wg_width, space_slice=space_slice, wg_shift=18):
    """Initializes waveguides and sources

    space       : The space between the PML and the structure
    wg_width    : The feed and probe waveguide width
    space_slice : The added space for the probe and source slices
    """
    bg_rho = np.zeros((Nx, Ny))
        
    # Input waveguide
    bg_rho[0:Npml+space,Ny//2-wg_width//2:Ny//2+wg_width//2] = 1

    # Input probe slice
    input_slice = Slice(x=np.array(Npml+1), 
        y=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice))
    input_slices = [input_slice]
    
    # Output waveguide 1
    bg_rho[int(Nx-Npml-space)::,Npml+space+wg_shift:Npml+space+wg_width+wg_shift] = 1
    # Output waveguide 2
    bg_rho[int(Nx-Npml-space)::,Ny-Npml-space-wg_width-wg_shift:Ny-Npml-space-wg_shift] = 1
    
    # Output probe slice 1
    output_slice1 = (Slice(x=np.array(Nx-Npml-1), 
        y=np.arange(Npml+space-space_slice+wg_shift, Npml+space+wg_width+space_slice+wg_shift)))
    # Output probe slice 2
    output_slice2 = (Slice(x=np.array(Nx-Npml-1), 
        y=np.arange(Ny-Npml-space-wg_width-wg_shift-space_slice, Ny-Npml-space-wg_shift+space_slice)))
    output_slices = [output_slice1, output_slice2]
            
    return bg_rho, input_slices, output_slices

def init_domain(epsrs):
    rods, design_region = init_design(epsrs)
    bg_rho, input_slices, output_slices = \
        init_guides(Nx, Ny, Npml, space=space, wg_width=wg_width, space_slice=space_slice, wg_shift=18)
    return bg_rho, design_region, rods, input_slices, output_slices

# %%
# Initialize the parametrization rho and the design region
epsrs = np.ones((num_dots, num_dots))*1
# epsrs = np.random.rand(num_dots, num_dots)*200-100
bg_rho, design_region, rods, input_slices, output_slices = init_domain(epsrs)

# Compute the permittivity from the design_region and the plasma rod permittivities
epsr_init = epsr_parameterization(epsrs, bg_rho, design_region, rods)

# Setup source
source1 = insert_mode(omega1, dl, input_slices[0].x, input_slices[0].y, epsr_init, m=1)
source2 = insert_mode(omega2, dl, input_slices[0].x, input_slices[0].y, epsr_init, m=1)

# Setup probe
probe1 = insert_mode(omega1, dl, output_slices[0].x, output_slices[0].y, epsr_init, m=1)
probe2 = insert_mode(omega2, dl, output_slices[1].x, output_slices[1].y, epsr_init, m=1)

# Simulate initial device
sim1, sim2, ax, fig = viz_sim(epsr_init, source1, source2, slices = input_slices + output_slices)

# %%
def callback_output_structure(iteration, of_list, epsrs):
    """Callback function to output fields and the structures (for making sweet gifs)"""
    epsrs = epsrs.reshape((num_dots, num_dots))
    epsr = epsr_parameterization(epsrs, bg_rho, design_region, rods)
    _, _, axs, fig = viz_sim(epsr, source1, source2, slices = input_slices + output_slices, log=iteration)
    plt.close()

# %%
# Define optimization objective
def mode_overlap(E1, E2):
    """Defines an overlap integral between the sim field and desired field
    """
    return npa.abs(npa.sum(npa.conj(E1)*E2))*1e6

Ex1, _, _ = sim1.solve(source1)
Ex2, _, _ = sim2.solve(source2)

E01 = mode_overlap(Ex1, probe1)
E02 = mode_overlap(Ex2, probe2)

# %%
def objective(epsrs):
    """Objective function called by optimizer
    
    1) Takes the density distribution as input
    2) Constructs epsr
    2) Runs the simulation
    3) Returns the overlap integral between the output wg field 
       and the desired mode field
    """
    epsrs = epsrs.reshape((num_dots, num_dots))
    epsr = epsr_parameterization(epsrs, bg_rho, design_region, rods)
    sim1.eps_r = epsr
    sim2.eps_r = epsr
    
    Ex1, _, _ = sim1.solve(source1)
    Ex2, _, _ = sim2.solve(source2)

    return mode_overlap(Ex1, probe1) / E01 * mode_overlap(Ex2, probe2) / E02

# Compute the gradient of the objective function using revere-mode differentiation
objective_jac = jacobian(objective, mode='reverse')

# Maximize the objective function using an ADAM optimizer
epsrs_optimum, _ = adam_optimize(objective, epsrs.flatten(), objective_jac,
                                 Nsteps=Nsteps, direction='max', step_size=step_size, callback=callback_output_structure)
# Out:
# Epoch:   1/500 | Duration: 55.14 secs | Value: 1.000000e+00
# Epoch:   2/500 | Duration: 22.29 secs | Value: 4.077266e-01
# Epoch:   3/500 | Duration: 42.10 secs | Value: 8.897308e-01
# Epoch:   4/500 | Duration: 62.26 secs | Value: 1.469663e+00
# Epoch:   5/500 | Duration: 22.80 secs | Value: 1.300392e+00
# Epoch:   6/500 | Duration: 27.18 secs | Value: 1.326725e+00
# Epoch:   7/500 | Duration: 23.28 secs | Value: 1.469146e+00
# Epoch:   8/500 | Duration: 33.24 secs | Value: 1.749446e+00
# Epoch:   9/500 | Duration: 25.59 secs | Value: 2.075764e+00
# Epoch:  10/500 | Duration: 25.27 secs | Value: 1.975019e+00
# Epoch:  11/500 | Duration: 29.59 secs | Value: 2.182799e+00
# Epoch:  12/500 | Duration: 35.18 secs | Value: 2.134534e+00
# Epoch:  13/500 | Duration: 26.76 secs | Value: 2.234643e+00
# Epoch:  14/500 | Duration: 24.22 secs | Value: 2.546984e+00
# Epoch:  15/500 | Duration: 23.89 secs | Value: 2.588964e+00
# Epoch:  16/500 | Duration: 47.58 secs | Value: 2.679314e+00
# Epoch:  17/500 | Duration: 33.07 secs | Value: 2.761705e+00
# Epoch:  18/500 | Duration: 40.42 secs | Value: 2.761450e+00
# Epoch:  19/500 | Duration: 33.85 secs | Value: 2.887342e+00
# Epoch:  20/500 | Duration: 34.98 secs | Value: 2.954713e+00
# Epoch:  21/500 | Duration: 39.19 secs | Value: 2.987005e+00
# Epoch:  22/500 | Duration: 32.70 secs | Value: 3.065725e+00
# Epoch:  23/500 | Duration: 33.04 secs | Value: 3.047998e+00
# Epoch:  24/500 | Duration: 31.65 secs | Value: 3.134480e+00
# Epoch:  25/500 | Duration: 30.60 secs | Value: 3.123607e+00
# Epoch:  26/500 | Duration: 30.82 secs | Value: 3.227161e+00
# Epoch:  27/500 | Duration: 31.98 secs | Value: 3.236303e+00
# Epoch:  28/500 | Duration: 32.83 secs | Value: 3.310184e+00
# Epoch:  29/500 | Duration: 39.59 secs | Value: 3.295094e+00
# Epoch:  30/500 | Duration: 58.04 secs | Value: 3.343746e+00
# Epoch:  31/500 | Duration: 46.81 secs | Value: 3.352826e+00
# Epoch:  32/500 | Duration: 41.50 secs | Value: 3.405152e+00
# Epoch:  33/500 | Duration: 38.17 secs | Value: 3.429931e+00
# Epoch:  34/500 | Duration: 38.90 secs | Value: 3.459895e+00
# Epoch:  35/500 | Duration: 38.48 secs | Value: 3.498404e+00
# Epoch:  36/500 | Duration: 37.47 secs | Value: 3.502247e+00
# Epoch:  37/500 | Duration: 39.89 secs | Value: 3.560952e+00
# Epoch:  38/500 | Duration: 39.50 secs | Value: 3.580104e+00
# Epoch:  39/500 | Duration: 39.41 secs | Value: 3.617800e+00
# Epoch:  40/500 | Duration: 38.88 secs | Value: 3.649546e+00
# Epoch:  41/500 | Duration: 37.82 secs | Value: 3.663296e+00
# Epoch:  42/500 | Duration: 39.66 secs | Value: 3.699437e+00
# Epoch:  43/500 | Duration: 39.11 secs | Value: 3.711143e+00
# Epoch:  44/500 | Duration: 60.28 secs | Value: 3.737480e+00
# Epoch:  45/500 | Duration: 46.80 secs | Value: 3.769829e+00
# Epoch:  46/500 | Duration: 44.53 secs | Value: 3.774898e+00
# Epoch:  47/500 | Duration: 45.05 secs | Value: 3.794834e+00
# Epoch:  48/500 | Duration: 53.17 secs | Value: 3.834698e+00
# Epoch:  49/500 | Duration: 44.05 secs | Value: 3.844537e+00
# Epoch:  50/500 | Duration: 48.15 secs | Value: 3.849289e+00
# Epoch:  51/500 | Duration: 44.62 secs | Value: 3.892326e+00
# Epoch:  52/500 | Duration: 31.38 secs | Value: 3.915839e+00
# Epoch:  53/500 | Duration: 32.37 secs | Value: 3.918677e+00
# Epoch:  54/500 | Duration: 33.21 secs | Value: 3.936009e+00
# Epoch:  55/500 | Duration: 31.58 secs | Value: 3.956252e+00
# Epoch:  56/500 | Duration: 32.42 secs | Value: 3.987038e+00
# Epoch:  57/500 | Duration: 33.90 secs | Value: 4.010485e+00
# Epoch:  58/500 | Duration: 35.68 secs | Value: 4.029784e+00
# Epoch:  59/500 | Duration: 33.02 secs | Value: 4.046493e+00
# Epoch:  60/500 | Duration: 33.04 secs | Value: 4.058775e+00
# Epoch:  61/500 | Duration: 35.91 secs | Value: 4.055308e+00
# Epoch:  62/500 | Duration: 32.64 secs | Value: 3.966737e+00
# Epoch:  63/500 | Duration: 32.33 secs | Value: 3.910476e+00
# Epoch:  64/500 | Duration: 32.52 secs | Value: 3.757825e+00
# Epoch:  65/500 | Duration: 34.47 secs | Value: 4.071842e+00
# Epoch:  66/500 | Duration: 34.10 secs | Value: 3.408842e+00
# Epoch:  67/500 | Duration: 32.76 secs | Value: 4.004315e+00
# Epoch:  68/500 | Duration: 31.80 secs | Value: 3.777904e+00
# Epoch:  69/500 | Duration: 32.33 secs | Value: 4.137947e+00
# Epoch:  70/500 | Duration: 32.71 secs | Value: 3.746096e+00
# Epoch:  71/500 | Duration: 31.23 secs | Value: 4.158146e+00
# Epoch:  72/500 | Duration: 69.50 secs | Value: 3.925432e+00
# Epoch:  73/500 | Duration: 39.25 secs | Value: 4.079573e+00
# Epoch:  74/500 | Duration: 41.87 secs | Value: 4.061999e+00
# Epoch:  75/500 | Duration: 39.84 secs | Value: 4.091875e+00
# Epoch:  76/500 | Duration: 37.99 secs | Value: 4.136436e+00
# Epoch:  77/500 | Duration: 39.34 secs | Value: 4.075034e+00
# Epoch:  78/500 | Duration: 44.87 secs | Value: 4.222499e+00
# Epoch:  79/500 | Duration: 39.79 secs | Value: 4.091061e+00
# Epoch:  80/500 | Duration: 34.93 secs | Value: 4.241291e+00
# Epoch:  81/500 | Duration: 38.83 secs | Value: 4.154646e+00
# Epoch:  82/500 | Duration: 33.17 secs | Value: 4.233257e+00
# Epoch:  83/500 | Duration: 34.73 secs | Value: 4.212482e+00
# Epoch:  84/500 | Duration: 39.32 secs | Value: 4.249273e+00
# Epoch:  85/500 | Duration: 32.11 secs | Value: 4.254156e+00
# Epoch:  86/500 | Duration: 30.83 secs | Value: 4.255877e+00
# Epoch:  87/500 | Duration: 31.44 secs | Value: 4.298526e+00
# Epoch:  88/500 | Duration: 33.50 secs | Value: 4.277807e+00
# Epoch:  89/500 | Duration: 32.56 secs | Value: 4.320710e+00
# Epoch:  90/500 | Duration: 31.45 secs | Value: 4.303582e+00
# Epoch:  91/500 | Duration: 32.34 secs | Value: 4.349235e+00
# Epoch:  92/500 | Duration: 31.66 secs | Value: 4.329859e+00
# Epoch:  93/500 | Duration: 30.48 secs | Value: 4.366504e+00
# Epoch:  94/500 | Duration: 71.54 secs | Value: 4.361392e+00
# Epoch:  95/500 | Duration: 69.85 secs | Value: 4.387781e+00
# Epoch:  96/500 | Duration: 53.65 secs | Value: 4.394735e+00
# Epoch:  97/500 | Duration: 40.21 secs | Value: 4.401507e+00
# Epoch:  98/500 | Duration: 44.94 secs | Value: 4.425914e+00
# Epoch:  99/500 | Duration: 50.74 secs | Value: 4.417433e+00
# Epoch: 100/500 | Duration: 41.37 secs | Value: 4.453393e+00
# Epoch: 101/500 | Duration: 37.12 secs | Value: 4.447050e+00
# Epoch: 102/500 | Duration: 39.72 secs | Value: 4.469777e+00
# Epoch: 103/500 | Duration: 37.96 secs | Value: 4.480853e+00
# Epoch: 104/500 | Duration: 42.36 secs | Value: 4.482798e+00
# Epoch: 105/500 | Duration: 42.26 secs | Value: 4.508185e+00
# Epoch: 106/500 | Duration: 39.98 secs | Value: 4.507227e+00
# Epoch: 107/500 | Duration: 47.78 secs | Value: 4.519348e+00
# Epoch: 108/500 | Duration: 42.96 secs | Value: 4.541162e+00
# Epoch: 109/500 | Duration: 38.66 secs | Value: 4.540015e+00
# Epoch: 110/500 | Duration: 40.16 secs | Value: 4.551549e+00
# Epoch: 111/500 | Duration: 58.04 secs | Value: 4.575386e+00
# Epoch: 112/500 | Duration: 67.37 secs | Value: 4.578833e+00
# Epoch: 113/500 | Duration: 68.39 secs | Value: 4.581665e+00
# Epoch: 114/500 | Duration: 56.88 secs | Value: 4.604353e+00
# Epoch: 115/500 | Duration: 46.70 secs | Value: 4.622384e+00
# Epoch: 116/500 | Duration: 39.30 secs | Value: 4.628048e+00
# Epoch: 117/500 | Duration: 39.20 secs | Value: 4.632631e+00
# Epoch: 118/500 | Duration: 40.39 secs | Value: 4.642555e+00
# Epoch: 119/500 | Duration: 41.01 secs | Value: 4.661499e+00
# Epoch: 120/500 | Duration: 46.75 secs | Value: 4.679868e+00
# Epoch: 121/500 | Duration: 37.71 secs | Value: 4.695378e+00
# Epoch: 122/500 | Duration: 39.42 secs | Value: 4.707675e+00
# Epoch: 123/500 | Duration: 45.05 secs | Value: 4.717462e+00
# Epoch: 124/500 | Duration: 41.59 secs | Value: 4.724267e+00
# Epoch: 125/500 | Duration: 41.78 secs | Value: 4.724043e+00
# Epoch: 126/500 | Duration: 39.31 secs | Value: 4.713435e+00
# Epoch: 127/500 | Duration: 38.68 secs | Value: 4.665052e+00
# Epoch: 128/500 | Duration: 37.67 secs | Value: 4.645515e+00
# Epoch: 129/500 | Duration: 36.58 secs | Value: 4.614925e+00
# Epoch: 130/500 | Duration: 36.61 secs | Value: 4.750376e+00
# Epoch: 131/500 | Duration: 44.51 secs | Value: 4.819087e+00
# Epoch: 132/500 | Duration: 33.34 secs | Value: 4.814616e+00
# Epoch: 133/500 | Duration: 32.51 secs | Value: 4.773857e+00
# Epoch: 134/500 | Duration: 48.85 secs | Value: 4.741838e+00
# Epoch: 135/500 | Duration: 41.33 secs | Value: 4.822914e+00
# Epoch: 136/500 | Duration: 32.66 secs | Value: 4.882005e+00
# Epoch: 137/500 | Duration: 30.95 secs | Value: 4.891489e+00
# Epoch: 138/500 | Duration: 36.54 secs | Value: 4.868607e+00
# Epoch: 139/500 | Duration: 38.89 secs | Value: 4.852755e+00
# Epoch: 140/500 | Duration: 39.63 secs | Value: 4.901580e+00
# Epoch: 141/500 | Duration: 37.46 secs | Value: 4.948321e+00
# Epoch: 142/500 | Duration: 39.11 secs | Value: 4.963694e+00
# Epoch: 143/500 | Duration: 31.21 secs | Value: 4.954433e+00
# Epoch: 144/500 | Duration: 33.15 secs | Value: 4.946133e+00
# Epoch: 145/500 | Duration: 32.62 secs | Value: 4.973468e+00
# Epoch: 146/500 | Duration: 42.03 secs | Value: 5.008494e+00
# Epoch: 147/500 | Duration: 42.73 secs | Value: 5.039499e+00
# Epoch: 148/500 | Duration: 43.10 secs | Value: 5.056757e+00
# Epoch: 149/500 | Duration: 42.05 secs | Value: 5.062792e+00
# Epoch: 150/500 | Duration: 48.36 secs | Value: 5.060390e+00
# Epoch: 151/500 | Duration: 44.55 secs | Value: 5.044497e+00
# Epoch: 152/500 | Duration: 32.43 secs | Value: 5.038390e+00
# Epoch: 153/500 | Duration: 44.99 secs | Value: 5.034332e+00
# Epoch: 154/500 | Duration: 32.51 secs | Value: 5.094437e+00
# Epoch: 155/500 | Duration: 36.46 secs | Value: 5.150598e+00
# Epoch: 156/500 | Duration: 31.56 secs | Value: 5.189882e+00
# Epoch: 157/500 | Duration: 38.40 secs | Value: 5.201943e+00
# Epoch: 158/500 | Duration: 47.41 secs | Value: 5.194147e+00
# Epoch: 159/500 | Duration: 42.68 secs | Value: 5.187656e+00
# Epoch: 160/500 | Duration: 38.32 secs | Value: 5.187505e+00
# Epoch: 161/500 | Duration: 29.54 secs | Value: 5.232045e+00
# Epoch: 162/500 | Duration: 36.15 secs | Value: 5.279607e+00
# Epoch: 163/500 | Duration: 39.82 secs | Value: 5.318878e+00
# Epoch: 164/500 | Duration: 29.80 secs | Value: 5.337209e+00
# Epoch: 165/500 | Duration: 40.42 secs | Value: 5.340552e+00
# Epoch: 166/500 | Duration: 33.85 secs | Value: 5.344858e+00
# Epoch: 167/500 | Duration: 30.40 secs | Value: 5.353177e+00
# Epoch: 168/500 | Duration: 29.60 secs | Value: 5.385064e+00
# Epoch: 169/500 | Duration: 29.06 secs | Value: 5.418795e+00
# Epoch: 170/500 | Duration: 28.91 secs | Value: 5.455425e+00
# Epoch: 171/500 | Duration: 25.12 secs | Value: 5.484564e+00
# Epoch: 172/500 | Duration: 24.27 secs | Value: 5.507922e+00
# Epoch: 173/500 | Duration: 24.39 secs | Value: 5.526582e+00
# Epoch: 174/500 | Duration: 24.06 secs | Value: 5.539963e+00
# Epoch: 175/500 | Duration: 23.94 secs | Value: 5.547660e+00
# Epoch: 176/500 | Duration: 37.44 secs | Value: 5.539346e+00
# Epoch: 177/500 | Duration: 35.84 secs | Value: 5.531890e+00
# Epoch: 178/500 | Duration: 27.05 secs | Value: 5.522884e+00
# Epoch: 179/500 | Duration: 37.23 secs | Value: 5.590365e+00
# Epoch: 180/500 | Duration: 28.22 secs | Value: 5.654408e+00
# Epoch: 181/500 | Duration: 30.83 secs | Value: 5.683505e+00
# Epoch: 182/500 | Duration: 40.04 secs | Value: 5.675116e+00
# Epoch: 183/500 | Duration: 38.83 secs | Value: 5.669678e+00
# Epoch: 184/500 | Duration: 35.04 secs | Value: 5.711987e+00
# Epoch: 185/500 | Duration: 33.09 secs | Value: 5.750400e+00
# Epoch: 186/500 | Duration: 30.91 secs | Value: 5.757185e+00
# Epoch: 187/500 | Duration: 25.02 secs | Value: 5.756401e+00
# Epoch: 188/500 | Duration: 33.40 secs | Value: 5.776979e+00
# Epoch: 189/500 | Duration: 26.76 secs | Value: 5.807453e+00
# Epoch: 190/500 | Duration: 25.26 secs | Value: 5.813712e+00
# Epoch: 191/500 | Duration: 25.46 secs | Value: 5.815593e+00
# Epoch: 192/500 | Duration: 24.58 secs | Value: 5.838652e+00
# Epoch: 193/500 | Duration: 25.62 secs | Value: 5.853251e+00
# Epoch: 194/500 | Duration: 25.56 secs | Value: 5.853380e+00
# Epoch: 195/500 | Duration: 29.20 secs | Value: 5.865032e+00
# Epoch: 196/500 | Duration: 24.27 secs | Value: 5.878127e+00
# Epoch: 197/500 | Duration: 29.23 secs | Value: 5.879982e+00
# Epoch: 198/500 | Duration: 23.92 secs | Value: 5.886542e+00
# Epoch: 199/500 | Duration: 25.27 secs | Value: 5.900682e+00
# Epoch: 200/500 | Duration: 25.45 secs | Value: 5.908070e+00
# Epoch: 201/500 | Duration: 24.94 secs | Value: 5.913981e+00
# Epoch: 202/500 | Duration: 26.50 secs | Value: 5.924546e+00
# Epoch: 203/500 | Duration: 27.09 secs | Value: 5.930436e+00
# Epoch: 204/500 | Duration: 34.71 secs | Value: 5.934542e+00
# Epoch: 205/500 | Duration: 28.93 secs | Value: 5.942846e+00
# Epoch: 206/500 | Duration: 29.91 secs | Value: 5.949115e+00
# Epoch: 207/500 | Duration: 34.02 secs | Value: 5.954549e+00
# Epoch: 208/500 | Duration: 32.89 secs | Value: 5.963580e+00
# Epoch: 209/500 | Duration: 39.32 secs | Value: 5.971341e+00
# Epoch: 210/500 | Duration: 32.56 secs | Value: 5.977020e+00
# Epoch: 211/500 | Duration: 31.54 secs | Value: 5.984206e+00
# Epoch: 212/500 | Duration: 31.34 secs | Value: 5.990931e+00
# Epoch: 213/500 | Duration: 32.79 secs | Value: 5.995844e+00
# Epoch: 214/500 | Duration: 33.84 secs | Value: 6.001755e+00
# Epoch: 215/500 | Duration: 32.48 secs | Value: 6.009164e+00
# Epoch: 216/500 | Duration: 31.69 secs | Value: 6.015556e+00
# Epoch: 217/500 | Duration: 33.56 secs | Value: 6.020607e+00
# Epoch: 218/500 | Duration: 40.24 secs | Value: 6.026052e+00
# Epoch: 219/500 | Duration: 32.07 secs | Value: 6.032093e+00
# Epoch: 220/500 | Duration: 34.76 secs | Value: 6.037629e+00
# Epoch: 221/500 | Duration: 31.69 secs | Value: 6.042240e+00
# Epoch: 222/500 | Duration: 29.91 secs | Value: 6.046694e+00
# Epoch: 223/500 | Duration: 26.16 secs | Value: 6.051760e+00
# Epoch: 224/500 | Duration: 25.95 secs | Value: 6.057225e+00
# Epoch: 225/500 | Duration: 25.47 secs | Value: 6.062455e+00
# Epoch: 226/500 | Duration: 25.73 secs | Value: 6.067251e+00
# Epoch: 227/500 | Duration: 28.68 secs | Value: 6.071752e+00
# Epoch: 228/500 | Duration: 26.95 secs | Value: 6.076056e+00
# Epoch: 229/500 | Duration: 34.95 secs | Value: 6.080238e+00
# Epoch: 230/500 | Duration: 25.28 secs | Value: 6.084358e+00
# Epoch: 231/500 | Duration: 30.11 secs | Value: 6.088444e+00
# Epoch: 232/500 | Duration: 24.99 secs | Value: 6.092317e+00
# Epoch: 233/500 | Duration: 25.00 secs | Value: 6.095534e+00
# Epoch: 234/500 | Duration: 25.22 secs | Value: 6.097806e+00
# Epoch: 235/500 | Duration: 25.35 secs | Value: 6.097978e+00
# Epoch: 236/500 | Duration: 33.00 secs | Value: 6.094941e+00
# Epoch: 237/500 | Duration: 35.11 secs | Value: 6.084120e+00
# Epoch: 238/500 | Duration: 27.70 secs | Value: 6.067029e+00
# Epoch: 239/500 | Duration: 35.88 secs | Value: 6.037298e+00
# Epoch: 240/500 | Duration: 26.54 secs | Value: 6.036013e+00
# Epoch: 241/500 | Duration: 28.31 secs | Value: 6.050483e+00
# Epoch: 242/500 | Duration: 26.85 secs | Value: 6.101583e+00
# Epoch: 243/500 | Duration: 28.51 secs | Value: 6.133676e+00
# Epoch: 244/500 | Duration: 30.07 secs | Value: 6.137806e+00
# Epoch: 245/500 | Duration: 36.69 secs | Value: 6.119201e+00
# Epoch: 246/500 | Duration: 39.28 secs | Value: 6.084815e+00
# Epoch: 247/500 | Duration: 26.85 secs | Value: 6.065528e+00
# Epoch: 248/500 | Duration: 25.78 secs | Value: 6.060593e+00
# Epoch: 249/500 | Duration: 29.72 secs | Value: 6.112191e+00
# Epoch: 250/500 | Duration: 41.89 secs | Value: 6.152466e+00
# Epoch: 251/500 | Duration: 33.29 secs | Value: 6.162968e+00
# Epoch: 252/500 | Duration: 31.89 secs | Value: 6.144598e+00
# Epoch: 253/500 | Duration: 32.71 secs | Value: 6.113317e+00
# Epoch: 254/500 | Duration: 30.33 secs | Value: 6.105233e+00
# Epoch: 255/500 | Duration: 37.47 secs | Value: 6.114515e+00
# Epoch: 256/500 | Duration: 41.01 secs | Value: 6.153883e+00
# Epoch: 257/500 | Duration: 37.41 secs | Value: 6.180226e+00
# Epoch: 258/500 | Duration: 40.29 secs | Value: 6.186586e+00
# Epoch: 259/500 | Duration: 36.43 secs | Value: 6.175797e+00
# Epoch: 260/500 | Duration: 39.82 secs | Value: 6.154178e+00
# Epoch: 261/500 | Duration: 38.99 secs | Value: 6.140490e+00
# Epoch: 262/500 | Duration: 36.01 secs | Value: 6.127843e+00
# Epoch: 263/500 | Duration: 38.82 secs | Value: 6.146834e+00
# Epoch: 264/500 | Duration: 38.49 secs | Value: 6.169267e+00
# Epoch: 265/500 | Duration: 44.84 secs | Value: 6.199041e+00
# Epoch: 266/500 | Duration: 42.34 secs | Value: 6.213867e+00
# Epoch: 267/500 | Duration: 26.15 secs | Value: 6.212607e+00
# Epoch: 268/500 | Duration: 26.88 secs | Value: 6.200032e+00
# Epoch: 269/500 | Duration: 26.97 secs | Value: 6.178000e+00
# Epoch: 270/500 | Duration: 30.37 secs | Value: 6.162705e+00
# Epoch: 271/500 | Duration: 42.54 secs | Value: 6.142616e+00
# Epoch: 272/500 | Duration: 32.52 secs | Value: 6.164479e+00
# Epoch: 273/500 | Duration: 30.23 secs | Value: 6.189179e+00
# Epoch: 274/500 | Duration: 32.10 secs | Value: 6.225085e+00
# Epoch: 275/500 | Duration: 30.56 secs | Value: 6.242427e+00
# Epoch: 276/500 | Duration: 31.22 secs | Value: 6.239689e+00
# Epoch: 277/500 | Duration: 33.05 secs | Value: 6.224036e+00
# Epoch: 278/500 | Duration: 36.17 secs | Value: 6.200356e+00
# Epoch: 279/500 | Duration: 29.56 secs | Value: 6.192503e+00
# Epoch: 280/500 | Duration: 30.23 secs | Value: 6.186655e+00
# Epoch: 281/500 | Duration: 30.55 secs | Value: 6.217435e+00
# Epoch: 282/500 | Duration: 32.48 secs | Value: 6.244203e+00
# Epoch: 283/500 | Duration: 35.31 secs | Value: 6.265093e+00
# Epoch: 284/500 | Duration: 36.80 secs | Value: 6.269879e+00
# Epoch: 285/500 | Duration: 27.19 secs | Value: 6.261219e+00
# Epoch: 286/500 | Duration: 25.67 secs | Value: 6.248570e+00
# Epoch: 287/500 | Duration: 25.55 secs | Value: 6.233503e+00
# Epoch: 288/500 | Duration: 27.66 secs | Value: 6.237459e+00
# Epoch: 289/500 | Duration: 25.52 secs | Value: 6.243583e+00
# Epoch: 290/500 | Duration: 27.57 secs | Value: 6.267560e+00
# Epoch: 291/500 | Duration: 30.78 secs | Value: 6.286087e+00
# Epoch: 292/500 | Duration: 37.39 secs | Value: 6.297611e+00
# Epoch: 293/500 | Duration: 39.67 secs | Value: 6.299385e+00
# Epoch: 294/500 | Duration: 28.32 secs | Value: 6.294043e+00
# Epoch: 295/500 | Duration: 35.85 secs | Value: 6.288040e+00
# Epoch: 296/500 | Duration: 30.28 secs | Value: 6.281271e+00
# Epoch: 297/500 | Duration: 34.41 secs | Value: 6.286389e+00
# Epoch: 298/500 | Duration: 30.93 secs | Value: 6.292579e+00
# Epoch: 299/500 | Duration: 33.15 secs | Value: 6.309100e+00
# Epoch: 300/500 | Duration: 42.56 secs | Value: 6.323046e+00
# Epoch: 301/500 | Duration: 32.34 secs | Value: 6.333646e+00
# Epoch: 302/500 | Duration: 32.28 secs | Value: 6.338346e+00
# Epoch: 303/500 | Duration: 32.13 secs | Value: 6.338961e+00
# Epoch: 304/500 | Duration: 31.70 secs | Value: 6.340105e+00
# Epoch: 305/500 | Duration: 39.31 secs | Value: 6.343950e+00
# Epoch: 306/500 | Duration: 39.83 secs | Value: 6.354519e+00
# Epoch: 307/500 | Duration: 32.71 secs | Value: 6.367183e+00
# Epoch: 308/500 | Duration: 32.06 secs | Value: 6.379542e+00
# Epoch: 309/500 | Duration: 32.97 secs | Value: 6.389593e+00
# Epoch: 310/500 | Duration: 33.78 secs | Value: 6.400406e+00
# Epoch: 311/500 | Duration: 56541.91 secs | Value: 6.416660e+00
# Epoch: 312/500 | Duration: 55.76 secs | Value: 6.438462e+00
# Epoch: 313/500 | Duration: 27.90 secs | Value: 6.434640e+00
# Epoch: 314/500 | Duration: 96.81 secs | Value: 6.297840e+00
# Epoch: 315/500 | Duration: 71.15 secs | Value: 5.966074e+00
# Epoch: 316/500 | Duration: 30.01 secs | Value: 5.856835e+00
# Epoch: 317/500 | Duration: 28.94 secs | Value: 6.156870e+00
# Epoch: 318/500 | Duration: 28.66 secs | Value: 5.674490e+00
# Epoch: 319/500 | Duration: 27.69 secs | Value: 6.286598e+00
# Epoch: 320/500 | Duration: 25.98 secs | Value: 5.987528e+00
# Epoch: 321/500 | Duration: 43.00 secs | Value: 6.378209e+00
# Epoch: 322/500 | Duration: 38.22 secs | Value: 6.014567e+00
# Epoch: 323/500 | Duration: 33.99 secs | Value: 6.331353e+00
# Epoch: 324/500 | Duration: 31.86 secs | Value: 6.221643e+00
# Epoch: 325/500 | Duration: 50.68 secs | Value: 6.387291e+00
# Epoch: 326/500 | Duration: 40.27 secs | Value: 6.363412e+00
# Epoch: 327/500 | Duration: 26.63 secs | Value: 6.376500e+00
# Epoch: 328/500 | Duration: 25.30 secs | Value: 3.080099e+00
# Epoch: 329/500 | Duration: 25.00 secs | Value: 3.326981e+00
# Epoch: 330/500 | Duration: 22.79 secs | Value: 3.188701e+00
# Epoch: 331/500 | Duration: 44.94 secs | Value: 3.758233e+00
# Epoch: 332/500 | Duration: 30.05 secs | Value: 3.343834e+00
# Epoch: 333/500 | Duration: 30.45 secs | Value: 4.487281e+00
# Epoch: 334/500 | Duration: 47.98 secs | Value: 4.926084e+00
# Epoch: 335/500 | Duration: 28.03 secs | Value: 4.051722e+00
# Epoch: 336/500 | Duration: 31.48 secs | Value: 4.425194e+00
# Epoch: 337/500 | Duration: 27.24 secs | Value: 4.552820e+00
# Epoch: 338/500 | Duration: 46.44 secs | Value: 4.847871e+00
# Epoch: 339/500 | Duration: 33.88 secs | Value: 5.063791e+00
# Epoch: 340/500 | Duration: 41.81 secs | Value: 4.701883e+00
# Epoch: 341/500 | Duration: 47.66 secs | Value: 4.730238e+00
# Epoch: 342/500 | Duration: 22.29 secs | Value: 4.984527e+00
# Epoch: 343/500 | Duration: 23.83 secs | Value: 4.853158e+00
# Epoch: 344/500 | Duration: 22.03 secs | Value: 4.670217e+00
# Epoch: 345/500 | Duration: 24.05 secs | Value: 4.808455e+00
# Epoch: 346/500 | Duration: 28.71 secs | Value: 4.994347e+00
# Epoch: 347/500 | Duration: 52.57 secs | Value: 4.981329e+00
# Epoch: 348/500 | Duration: 55.48 secs | Value: 5.045118e+00
# Epoch: 349/500 | Duration: 38.31 secs | Value: 5.189420e+00
# Epoch: 350/500 | Duration: 30.76 secs | Value: 5.212799e+00
# Epoch: 351/500 | Duration: 39.07 secs | Value: 5.223368e+00
# Epoch: 352/500 | Duration: 31.43 secs | Value: 5.307477e+00
# Epoch: 353/500 | Duration: 27.81 secs | Value: 5.265421e+00
# Epoch: 354/500 | Duration: 25.69 secs | Value: 5.250684e+00
# Epoch: 355/500 | Duration: 30.12 secs | Value: 5.394150e+00
# Epoch: 356/500 | Duration: 22.41 secs | Value: 5.433101e+00
# Epoch: 357/500 | Duration: 27.65 secs | Value: 5.489199e+00
# Epoch: 358/500 | Duration: 24.04 secs | Value: 5.562976e+00
# Epoch: 359/500 | Duration: 24.03 secs | Value: 5.562326e+00
# Epoch: 360/500 | Duration: 20.37 secs | Value: 5.607607e+00
# Epoch: 361/500 | Duration: 26.36 secs | Value: 5.668364e+00
# Epoch: 362/500 | Duration: 28.37 secs | Value: 5.653761e+00
# Epoch: 363/500 | Duration: 34.30 secs | Value: 5.680267e+00
# Epoch: 364/500 | Duration: 49.80 secs | Value: 5.733514e+00
# Epoch: 365/500 | Duration: 47.08 secs | Value: 5.752432e+00
# Epoch: 366/500 | Duration: 50.65 secs | Value: 5.814191e+00
# Epoch: 367/500 | Duration: 56.29 secs | Value: 5.831779e+00
# Epoch: 368/500 | Duration: 43.22 secs | Value: 5.855436e+00
# Epoch: 369/500 | Duration: 49.26 secs | Value: 5.902507e+00
# Epoch: 370/500 | Duration: 55.70 secs | Value: 5.908066e+00
# Epoch: 371/500 | Duration: 58.51 secs | Value: 5.955286e+00
# Epoch: 372/500 | Duration: 55.03 secs | Value: 5.962392e+00
# Epoch: 373/500 | Duration: 44.66 secs | Value: 6.018651e+00
# Epoch: 374/500 | Duration: 49.39 secs | Value: 6.036793e+00
# Epoch: 375/500 | Duration: 44.00 secs | Value: 6.076466e+00
# Epoch: 376/500 | Duration: 50.08 secs | Value: 6.080178e+00
# Epoch: 377/500 | Duration: 46.73 secs | Value: 6.089715e+00
# Epoch: 378/500 | Duration: 46.38 secs | Value: 6.093106e+00
# Epoch: 379/500 | Duration: 51.44 secs | Value: 6.093833e+00
# Epoch: 380/500 | Duration: 38.64 secs | Value: 6.118003e+00
# Epoch: 381/500 | Duration: 21.26 secs | Value: 6.130380e+00
# Epoch: 382/500 | Duration: 25.22 secs | Value: 6.164495e+00
# Epoch: 383/500 | Duration: 23.76 secs | Value: 6.177971e+00
# Epoch: 384/500 | Duration: 22.72 secs | Value: 6.186984e+00
# Epoch: 385/500 | Duration: 24.27 secs | Value: 6.205016e+00
# Epoch: 386/500 | Duration: 29.84 secs | Value: 6.213881e+00
# Epoch: 387/500 | Duration: 29.86 secs | Value: 6.227647e+00
# Epoch: 388/500 | Duration: 43.90 secs | Value: 6.232764e+00
# Epoch: 389/500 | Duration: 43.28 secs | Value: 6.236062e+00
# Epoch: 390/500 | Duration: 28.95 secs | Value: 6.250435e+00
# Epoch: 391/500 | Duration: 35.48 secs | Value: 6.259074e+00
# Epoch: 392/500 | Duration: 35.29 secs | Value: 6.261886e+00
# Epoch: 393/500 | Duration: 31.70 secs | Value: 6.273415e+00
# Epoch: 394/500 | Duration: 30.91 secs | Value: 6.286644e+00
# Epoch: 395/500 | Duration: 50.62 secs | Value: 6.291505e+00
# Epoch: 396/500 | Duration: 34.73 secs | Value: 6.295711e+00
# Epoch: 397/500 | Duration: 40.85 secs | Value: 6.303931e+00
# Epoch: 398/500 | Duration: 27.85 secs | Value: 6.309291e+00
# Epoch: 399/500 | Duration: 29.23 secs | Value: 6.312348e+00
# Epoch: 400/500 | Duration: 28.77 secs | Value: 6.319685e+00
# Epoch: 401/500 | Duration: 26.65 secs | Value: 6.329222e+00
# Epoch: 402/500 | Duration: 29.16 secs | Value: 6.336215e+00
# Epoch: 403/500 | Duration: 27.63 secs | Value: 6.342857e+00
# Epoch: 404/500 | Duration: 26.13 secs | Value: 6.351538e+00
# Epoch: 405/500 | Duration: 22.76 secs | Value: 6.359736e+00
# Epoch: 406/500 | Duration: 24.64 secs | Value: 6.365751e+00
# Epoch: 407/500 | Duration: 37.27 secs | Value: 6.371561e+00
# Epoch: 408/500 | Duration: 26.23 secs | Value: 6.378512e+00
# Epoch: 409/500 | Duration: 49.97 secs | Value: 6.385658e+00
# Epoch: 410/500 | Duration: 32.33 secs | Value: 6.392439e+00
# Epoch: 411/500 | Duration: 25.74 secs | Value: 6.399551e+00
# Epoch: 412/500 | Duration: 36.22 secs | Value: 6.406917e+00
# Epoch: 413/500 | Duration: 31.41 secs | Value: 6.413807e+00
# Epoch: 414/500 | Duration: 37.02 secs | Value: 6.420697e+00
# Epoch: 415/500 | Duration: 27.27 secs | Value: 6.428227e+00
# Epoch: 416/500 | Duration: 53.34 secs | Value: 6.435836e+00
# Epoch: 417/500 | Duration: 37.42 secs | Value: 6.443048e+00
# Epoch: 418/500 | Duration: 32.75 secs | Value: 6.450307e+00
# Epoch: 419/500 | Duration: 41.31 secs | Value: 6.457613e+00
# Epoch: 420/500 | Duration: 40.67 secs | Value: 6.464575e+00
# Epoch: 421/500 | Duration: 42.85 secs | Value: 6.471595e+00
# Epoch: 422/500 | Duration: 36.48 secs | Value: 6.479018e+00
# Epoch: 423/500 | Duration: 35.17 secs | Value: 6.486334e+00
# Epoch: 424/500 | Duration: 56.18 secs | Value: 6.493462e+00
# Epoch: 425/500 | Duration: 24.51 secs | Value: 6.500693e+00
# Epoch: 426/500 | Duration: 28.44 secs | Value: 6.507672e+00
# Epoch: 427/500 | Duration: 34.65 secs | Value: 6.513880e+00
# Epoch: 428/500 | Duration: 24.79 secs | Value: 6.518572e+00
# Epoch: 429/500 | Duration: 30.67 secs | Value: 6.520819e+00
# Epoch: 430/500 | Duration: 41.73 secs | Value: 6.515571e+00
# Epoch: 431/500 | Duration: 33.66 secs | Value: 6.503004e+00
# Epoch: 432/500 | Duration: 39.77 secs | Value: 6.461034e+00
# Epoch: 433/500 | Duration: 26.84 secs | Value: 6.448406e+00
# Epoch: 434/500 | Duration: 23.71 secs | Value: 6.419359e+00
# Epoch: 435/500 | Duration: 42.98 secs | Value: 6.513895e+00
# Epoch: 436/500 | Duration: 26.98 secs | Value: 6.567827e+00
# Epoch: 437/500 | Duration: 29.78 secs | Value: 6.570607e+00
# Epoch: 438/500 | Duration: 55.20 secs | Value: 6.536521e+00
# Epoch: 439/500 | Duration: 78.83 secs | Value: 6.494601e+00
# Epoch: 440/500 | Duration: 27.94 secs | Value: 6.536391e+00
# Epoch: 441/500 | Duration: 29.23 secs | Value: 6.578607e+00
# Epoch: 442/500 | Duration: 27.05 secs | Value: 6.595752e+00
# Epoch: 443/500 | Duration: 26.86 secs | Value: 6.578136e+00
# Epoch: 444/500 | Duration: 59.86 secs | Value: 6.545075e+00
# Epoch: 445/500 | Duration: 51.29 secs | Value: 6.550024e+00
# Epoch: 446/500 | Duration: 40.92 secs | Value: 6.561076e+00
# Epoch: 447/500 | Duration: 44.29 secs | Value: 6.599114e+00
# Epoch: 448/500 | Duration: 30.70 secs | Value: 6.619439e+00
# Epoch: 449/500 | Duration: 24.98 secs | Value: 6.632869e+00
# Epoch: 450/500 | Duration: 29.69 secs | Value: 6.637891e+00
# Epoch: 451/500 | Duration: 37.76 secs | Value: 6.640065e+00
# Epoch: 452/500 | Duration: 22.52 secs | Value: 6.632900e+00
# Epoch: 453/500 | Duration: 22.58 secs | Value: 6.597017e+00
# Epoch: 454/500 | Duration: 22.97 secs | Value: 6.512311e+00
# Epoch: 455/500 | Duration: 53.67 secs | Value: 6.255926e+00
# Epoch: 456/500 | Duration: 33.92 secs | Value: 6.554938e+00
# Epoch: 457/500 | Duration: 24.07 secs | Value: 6.660099e+00
# Epoch: 458/500 | Duration: 24.45 secs | Value: 6.657443e+00
# Epoch: 459/500 | Duration: 24.38 secs | Value: 6.578307e+00
# Epoch: 460/500 | Duration: 25.57 secs | Value: 6.408419e+00
# Epoch: 461/500 | Duration: 26.13 secs | Value: 6.584843e+00
# Epoch: 462/500 | Duration: 27.76 secs | Value: 6.671365e+00
# Epoch: 463/500 | Duration: 36.90 secs | Value: 6.682267e+00
# Epoch: 464/500 | Duration: 26.79 secs | Value: 6.634092e+00
# Epoch: 465/500 | Duration: 30.69 secs | Value: 6.541512e+00
# Epoch: 466/500 | Duration: 26.55 secs | Value: 6.611121e+00
# Epoch: 467/500 | Duration: 26.73 secs | Value: 6.654889e+00
# Epoch: 468/500 | Duration: 29.65 secs | Value: 6.700302e+00
# Epoch: 469/500 | Duration: 23.60 secs | Value: 6.709246e+00
# Epoch: 470/500 | Duration: 22.23 secs | Value: 6.693113e+00
# Epoch: 471/500 | Duration: 21.03 secs | Value: 6.664727e+00
# Epoch: 472/500 | Duration: 21.78 secs | Value: 6.607459e+00
# Epoch: 473/500 | Duration: 22.32 secs | Value: 6.630890e+00
# Epoch: 474/500 | Duration: 23.65 secs | Value: 6.624352e+00
# Epoch: 475/500 | Duration: 20.82 secs | Value: 6.682687e+00
# Epoch: 476/500 | Duration: 22.92 secs | Value: 6.709511e+00
# Epoch: 477/500 | Duration: 22.91 secs | Value: 6.730108e+00
# Epoch: 478/500 | Duration: 24.42 secs | Value: 6.740484e+00
# Epoch: 479/500 | Duration: 24.29 secs | Value: 6.746040e+00
# Epoch: 480/500 | Duration: 23.49 secs | Value: 6.749676e+00
# Epoch: 481/500 | Duration: 25.67 secs | Value: 6.750809e+00
# Epoch: 482/500 | Duration: 24.41 secs | Value: 6.745673e+00
# Epoch: 483/500 | Duration: 24.25 secs | Value: 6.712900e+00
# Epoch: 484/500 | Duration: 24.88 secs | Value: 6.604025e+00
# Epoch: 485/500 | Duration: 24.07 secs | Value: 6.195459e+00
# Epoch: 486/500 | Duration: 26.10 secs | Value: 6.684904e+00
# Epoch: 487/500 | Duration: 24.56 secs | Value: 6.759109e+00
# Epoch: 488/500 | Duration: 24.75 secs | Value: 6.585474e+00
# Epoch: 489/500 | Duration: 23.80 secs | Value: 6.437385e+00
# Epoch: 490/500 | Duration: 25.54 secs | Value: 6.285247e+00
# Epoch: 491/500 | Duration: 20.40 secs | Value: 6.766716e+00
# Epoch: 492/500 | Duration: 22.18 secs | Value: 6.116131e+00
# Epoch: 493/500 | Duration: 19.61 secs | Value: 5.991365e+00
# Epoch: 494/500 | Duration: 20.84 secs | Value: 6.179289e+00
# Epoch: 495/500 | Duration: 19.75 secs | Value: 6.085444e+00
# Epoch: 496/500 | Duration: 22.74 secs | Value: 6.717544e+00
# Epoch: 497/500 | Duration: 19.71 secs | Value: 6.250108e+00
# Epoch: 498/500 | Duration: 20.46 secs | Value: 6.627365e+00
# Epoch: 499/500 | Duration: 21.11 secs | Value: 6.173613e+00
# Epoch: 500/500 | Duration: 20.32 secs | Value: 6.700025e+00

# %%
# epsrs = epsr_parameterization(epsrs_optimum, bg_rho, design_region, rods)
# _, _, axs, fig = viz_sim(epsrs, source1, source2, slices = input_slices + output_slices)
obj1 = []
obj2 = []
for i in range(499, Nsteps):
    E1 = np.loadtxt('multiplex/tm/Ex1_%03d.csv' % i, delimiter=',')
    E2 = np.loadtxt('multiplex/tm/Ex2_%03d.csv' % i, delimiter=',')    
    epsr = np.loadtxt('multiplex/tm/epsr_%03d.csv' % i, delimiter=',')
    
    fig, axs = plt.subplots(1, 3, constrained_layout=True, figsize=(9,3))
    epsr_graph = np.array(epsr, copy=True)
    epsr_graph[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 0
    
#     obj1.append(mode_overlap(E1, probe1) / E01)
#     obj2.append(mode_overlap(E2, probe2) / E02)
    
#     axs[0].set_title('$\lambda_1$ = %.2f $\mu$m' % (299792458/(omega1/2/np.pi)/1e-6))
#     axs[1].set_title('$\lambda_2$ = %.2f $\mu$m' % (299792458/(omega2/2/np.pi)/1e-6))
    for ax in axs:
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.set_yticks([])
        ax.set_xticks([])
#     for ax in axs[1][0:2]:
#         ax.set_xlabel('Epoch')
#         ax.set_ylabel('Percent Change in Objective')
    
    abslt(E1, outline=epsr_graph, ax=axs[0], cbar=False, vmax=1e-7)
#     axs[1,0].plot(obj1)
    abslt(E2, outline=epsr_graph, ax=axs[1], cbar=True, vmax=1e-7)
#     axs[1,1].plot(obj2)
    real(epsr, ax=axs[2], cmap='RdGy', cbar=True, vmin=-6, vmax=1)
#     axs[-1,-1].axis('off')
    plt.savefig('multiplex/tm/normalized_%03d.png' % i, dpi=70)
    plt.close()

# %%
grid = (epsr_train_max-epsr_train_min) * (npa.arctan(epsrs_optimum)/np.pi + 0.5) + epsr_train_min
print(grid)
make_gif('multiplex_te.gif', 475, 'multiplex/te')
