# %%
import numpy as np
import autograd.numpy as npa
import matplotlib as mpl
mpl.rcParams['figure.dpi']=100
import matplotlib.pylab as plt
from autograd.scipy.signal import convolve as conv
from skimage.draw import circle
import ceviche
from ceviche import fdfd_ez, jacobian, fdfd_hz
from ceviche.optimizers import adam_optimize
from ceviche.modes import insert_mode
import collections
from make_gif import make_gif
# Create a container for our slice coords to be used for sources and probes
Slice = collections.namedtuple('Slice', 'x y')

# %%
#----------------- Simulation Constants -----------------#
# The angular frequencies
omega1=2*np.pi*200e12
# Wavevector
k0=omega1/299792458
# Spatial resolution in meters
dl=40e-9
# Number of pixels in x-direction
Nx=240
# Number of pixels in y-direction
Ny=240
# Number of pixels in the PMLs in each direction
Npml=40
# Minimum value of the relative permittivity
epsr_train_min=-6.0
epsr_train_max=1.0
# Maximum value of the relative permittivity
epsr_design=1.0
epsr_bckgd=12.0

#------------------- Domain Constants -------------------#
# Space between the PMLs and the design region (in pixels)
space=20
# Width of the waveguide (in pixels)
wg_width=24
# Length in pixels of the source/probe slices on each side of the center point
space_slice=16
# Number of dots in a row/column
num_dots=6
# Radius of dots
circle_rad=int((Nx-2*(Npml+space))/(2*num_dots))
# Lattice constant
ra=1

#---------------- Optimization Constants ----------------#
# Number of epochs in the optimization 
Nsteps=200
# Step size for the Adam optimizer
step_size=1e-4

#------------------ Graphing Constants ------------------#
Emax=0
emin=-6
emax=1

# %%
def init_design(epsrs, Nx=Nx, Ny=Ny, Npml=Npml, space=space, num_dots=num_dots, circle_rad=circle_rad, ra=ra):
    # Selector for each plasma rod
    rods = [np.zeros((Nx, Ny)) for i in range(num_dots**2)]
    # Selector for entire design region
    design_region = np.zeros((Nx, Ny))
    design_region[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 1
    
    # Initialize selector for circular plasma rods
    center_x = Npml+space+circle_rad
    for i in range(num_dots):
        center_y = Npml+space+circle_rad
        for j in range(num_dots):
            r, c = circle(center_x, center_y, circle_rad*ra)
            rods[j + i*num_dots][r, c] = 1
            center_y = center_y + 2*circle_rad
        center_x = center_x + 2*circle_rad
        
    return rods, design_region
    
def init_guides(Nx=Nx, Ny=Ny, Npml=Npml, space=space, wg_width=wg_width, space_slice=space_slice, wg_shift=9):
    """Initializes waveguides and sources

    space       : The space between the PML and the structure
    wg_width    : The feed and probe waveguide width
    space_slice : The added space for the probe and source slices
    """
    bg_rho = np.zeros((Nx, Ny))
        
    # Data waveguide 1
    bg_rho[0:int(Npml+space),Ny//2-wg_width//2:Ny//2+wg_width//2] = 1
    # Data probe slice 
    data_slice = Slice(x=np.array(Npml+1),
                        y=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice))
    input_slices = [data_slice]
    
    # Output waveguide
    bg_rho[int(Nx-Npml-space)::,Ny//2-wg_width//2:Ny//2+wg_width//2] = 1
    # Ground waveguide
    bg_rho[Nx//2-wg_width//2:Nx//2+wg_width//2,int(Ny-Npml-space)::] = 1
    
    # Output probe slice
    output_slice = Slice(x=np.array(Nx-Npml-1),
                         y=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice))
    #Ground probe slice
    ground_slice = Slice(x=np.arange(Ny//2-wg_width//2-space_slice, Ny//2+wg_width//2+space_slice),
                         y=np.array(Ny-Npml-1))
    output_slices = [output_slice, ground_slice]
            
    return bg_rho, input_slices, output_slices

def init_domain(epsrs):
    rods, design_region = init_design(epsrs)
    bg_rho, input_slices, output_slices = \
        init_guides(Nx, Ny, Npml, space=space, wg_width=wg_width, space_slice=space_slice, wg_shift=18)
    return bg_rho, design_region, rods, input_slices, output_slices

# %%
# set the colormap and centre the colorbar
class MidpointNormalize(mpl.colors.Normalize):
    """
    Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)

    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        mpl.colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))
    
def real(val, outline=None, ax=None, cbar=False, cmap='RdBu', outline_alpha=0.5, vmin=None, vmax=None):
    """Plots the real part of 'val', optionally overlaying an outline of 'outline'
    """
    if ax is None:
        fig, ax = plt.subplots(1, 1, constrained_layout=True)
    
    if vmin is None:
        vmax = np.real(val).max()
        vmin = np.real(val).min()
    h = ax.imshow(np.real(val.T), cmap=cmap, origin='lower left', clim=(vmin, vmax), \
                  norm=MidpointNormalize(midpoint=0,vmin=vmin,vmax=vmax))
    
    if outline is not None:
        ax.contour(outline.T, 0, colors='k', alpha=outline_alpha)
    
    if cbar:
        cbar = plt.colorbar(h, ax=ax)
        cbar.set_ticks([-6, 0, 1])
        cbar.set_ticklabels(['-6', '0', '1'])
        cbar.ax.set_ylabel('Relative Permittivity')
    
    return ax

def abslt(val, outline=None, ax=None, cbar=False, cmap='magma', outline_alpha=0.5, outline_val=None, vmax=None):
    """Plots the absolute value of 'val', optionally overlaying an outline of 'outline'
    """
    if ax is None:
        fig, ax = plt.subplots(1, 1, constrained_layout=True)      
    
    if vmax is None:
        vmax = np.abs(val).max()
    h = ax.imshow(np.abs(val.T), cmap=cmap, origin='lower left', vmin=0, vmax=vmax)
    
    if outline_val is None and outline is not None: outline_val = 0.5*(outline.min()+outline.max())
    if outline is not None:
        ax.contour(outline.T, [outline_val], colors='w', alpha=outline_alpha)

    if cbar:
        cbar = plt.colorbar(h, ax=ax)
        cbar.set_ticks([])
        cbar.ax.set_ylabel('Electric Field Strength')
    
    return ax

# %%
def viz_sim(epsr, data, slices=[], log=0):
    """Solve and visualize a simulation with permittivity 'epsr'
    """
    global emin, emax, Emax
    
    simulation = fdfd_hz(omega1, dl, epsr, [Npml, Npml])
    Ex, _, _ = simulation.solve(data)
    
    epsr_graph = np.array(epsr, copy=True)
    epsr_graph[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 0
    
    fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(16,4))
    abslt(Ex, outline=epsr_graph, ax=axs[0], cbar=True)
    real(epsr, ax=axs[1], cmap='RdGy', cbar=True, vmin=emin, vmax=emax)
    for sl in slices:
        for ax in axs:
            try:
                ax.plot(sl.x*np.ones(len(sl.y)), sl.y, 'w-', alpha=0.5)
            except:
                ax.plot(sl.x, sl.y*np.ones(len(sl.x)), 'w-', alpha=0.5)
        
    if log:
        if np.abs(Ex).max() > Emax:
            Emax=np.abs(Ex).max()
        np.savetxt('straight_tm/Ex_%03d.csv' % log, np.abs(Ex), delimiter=',')
        
        if epsr.min() < emin:
            emin=epsr.min()
        if epsr.max() > emax:
            emax=epsr.max()
        np.savetxt('straight_tm/epsr_%03d.csv' % log, epsr, delimiter=',')
    
    return (simulation, axs, fig)

def mask_combine_rho(rods, bg_rho, design_region):
    """Utility function for combining the design region rho and the background rho
    """
    train = (epsr_train_max-epsr_train_min)*rods*(rods!=0).astype(np.float) + epsr_train_min*(rods!=0).astype(np.float)
    print(train.min())
    design = epsr_design*design_region*(rods==0).astype(np.float)
    bckgd = epsr_bckgd*bg_rho*(design_region==0).astype(np.float)
    return train + design + bckgd

def scale_epsrs(epsrs, rods):
    epsrs = epsrs.flatten()
    epsrs = npa.arctan(epsrs) / np.pi + 0.5 
    rho = np.zeros(rods[0].shape)
    for i in range(len(epsrs)):
        rho += epsrs[i]*rods[i]
    return rho

def epsr_parameterization(epsrs, bg_rho, design_region, rods):
    """Defines the parameterization steps for constructing rho
    """
    rods = scale_epsrs(epsrs, rods)
    return mask_combine_rho(rods, bg_rho, design_region)

# %%
# Initialize the parametrization rho and the design region
epsrs = np.ones((num_dots, num_dots))*0
bg_rho, design_region, rods, input_slices, output_slices = init_domain(epsrs)

# Compute the permittivity from the design_region and the plasma rod permittivities
epsr_init = epsr_parameterization(epsrs, bg_rho, design_region, rods)

# Setup sources
data = insert_mode(omega1, dl, input_slices[0].x, input_slices[0].y, epsr_init, m=1)

# Setup probes
probe = insert_mode(omega1, dl, output_slices[0].x, output_slices[0].y, epsr_init, m=1)
ground = insert_mode(omega1, dl, output_slices[1].x, output_slices[1].y, epsr_init, m=1)

# Simulate initial device
simulation, ax, fig = viz_sim(epsr_init, data, slices = input_slices + output_slices)
# Out:
# -2.5

# %%
def callback_output_structure(iteration, of_list, epsrs):
    """Callback function to output fields and the structures (for making sweet gifs)"""
    epsrs = epsrs.reshape((num_dots, num_dots))
    epsr = epsr_parameterization(epsrs, bg_rho, design_region, rods)
    _, axs, fig = viz_sim(epsr, data, slices = input_slices + output_slices, log=iteration)
    plt.close()

# %%
# Define optimization objective
def mode_overlap(E1, E2):
    """Defines an overlap integral between the sim field and desired field
    """
    return npa.abs(npa.sum(npa.conj(E1)*E2))*1e6

# %%
Ex_0, _, _ = simulation.solve(data)
normal = mode_overlap(Ex_0, probe)

def objective(epsrs):
    """Objective function called by optimizer
    1) Takes the density distribution as input
    2) Constructs epsr
    2) Runs the simulation
    3) Returns the overlap integral between the output wg field 
       and the desired mode field
    """
    epsrs = epsrs.reshape((num_dots, num_dots))
    epsr = epsr_parameterization(epsrs, bg_rho, design_region, rods)
    simulation.eps_r = epsr

    Ex, _, _ = simulation.solve(data)
    return mode_overlap(Ex, probe) / normal
    
def simulate():
    # Compute the gradient of the objective function using revere-mode differentiation
    objective_jac = jacobian(objective, mode='reverse')

    # Maximize the objective function using an ADAM optimizer
    epsrs_optimum, _ = adam_optimize(objective, epsrs.flatten(), objective_jac,
                            Nsteps=Nsteps, direction='max', step_size=step_size, callback=callback_output_structure)
    return epsrs_optimum.reshape((num_dots, num_dots))

# %%
# Simulate optimal device
epsrs_optimum = simulate()
print(epsrs_optimum)
epsrs = epsr_parameterization(epsrs_optimum, bg_rho, design_region, rods)
_, ax, fig = viz_sim(epsrs, data, slices = input_slices + output_slices)
# Out:
# Epoch:   1/200 | Duration: 2.45 secs | Value: 1.000000e+00
# Epoch:   2/200 | Duration: 2.38 secs | Value: 1.668969e+00
# Epoch:   3/200 | Duration: 2.40 secs | Value: 2.818542e+00
# Epoch:   4/200 | Duration: 2.37 secs | Value: 1.899794e+00
# Epoch:   5/200 | Duration: 2.58 secs | Value: 9.424594e+00
# Epoch:   6/200 | Duration: 3.41 secs | Value: 2.664021e+00
# Epoch:   7/200 | Duration: 2.53 secs | Value: 5.150707e+00
# Epoch:   8/200 | Duration: 2.60 secs | Value: 5.630120e+00
# Epoch:   9/200 | Duration: 2.30 secs | Value: 1.487922e+01
# Epoch:  10/200 | Duration: 3.12 secs | Value: 1.185940e+01
# Epoch:  11/200 | Duration: 3.69 secs | Value: 1.056511e+01
# Epoch:  12/200 | Duration: 2.62 secs | Value: 1.068263e+01
# Epoch:  13/200 | Duration: 2.24 secs | Value: 1.180953e+01
# Epoch:  14/200 | Duration: 2.38 secs | Value: 1.394637e+01
# Epoch:  15/200 | Duration: 2.34 secs | Value: 1.634188e+01
# Epoch:  16/200 | Duration: 2.28 secs | Value: 1.328286e+01
# Epoch:  17/200 | Duration: 2.39 secs | Value: 1.586279e+01
# Epoch:  18/200 | Duration: 2.29 secs | Value: 1.917946e+01
# Epoch:  19/200 | Duration: 2.26 secs | Value: 1.429114e+01
# Epoch:  20/200 | Duration: 2.75 secs | Value: 1.716371e+01
# Epoch:  21/200 | Duration: 2.83 secs | Value: 1.628958e+01
# Epoch:  22/200 | Duration: 2.58 secs | Value: 1.680056e+01
# Epoch:  23/200 | Duration: 2.59 secs | Value: 1.798634e+01
# Epoch:  24/200 | Duration: 5.06 secs | Value: 1.855778e+01
# Epoch:  25/200 | Duration: 6.06 secs | Value: 1.645816e+01
# Epoch:  26/200 | Duration: 4.68 secs | Value: 1.860060e+01
# Epoch:  27/200 | Duration: 4.64 secs | Value: 1.838218e+01
# Epoch:  28/200 | Duration: 4.78 secs | Value: 1.923461e+01
# Epoch:  29/200 | Duration: 5.17 secs | Value: 2.050469e+01
# Epoch:  30/200 | Duration: 4.90 secs | Value: 1.905805e+01
# Epoch:  31/200 | Duration: 2.36 secs | Value: 2.013055e+01
# Epoch:  32/200 | Duration: 2.36 secs | Value: 1.983484e+01
# Epoch:  33/200 | Duration: 2.32 secs | Value: 2.122122e+01
# Epoch:  34/200 | Duration: 2.50 secs | Value: 2.113738e+01
# Epoch:  35/200 | Duration: 3.19 secs | Value: 2.167653e+01
# Epoch:  36/200 | Duration: 2.17 secs | Value: 2.129115e+01
# Epoch:  37/200 | Duration: 2.76 secs | Value: 2.119180e+01
# Epoch:  38/200 | Duration: 4.13 secs | Value: 2.207505e+01
# Epoch:  39/200 | Duration: 2.27 secs | Value: 2.240263e+01
# Epoch:  40/200 | Duration: 2.65 secs | Value: 2.228065e+01
# Epoch:  41/200 | Duration: 3.18 secs | Value: 2.206382e+01
# Epoch:  42/200 | Duration: 3.05 secs | Value: 2.222077e+01
# Epoch:  43/200 | Duration: 2.37 secs | Value: 2.196490e+01
# Epoch:  44/200 | Duration: 2.58 secs | Value: 2.176754e+01
# Epoch:  45/200 | Duration: 2.88 secs | Value: 2.237700e+01
# Epoch:  46/200 | Duration: 3.24 secs | Value: 1.989525e+01
# Epoch:  47/200 | Duration: 2.37 secs | Value: 2.046263e+01
# Epoch:  48/200 | Duration: 2.56 secs | Value: 1.954103e+01
# Epoch:  49/200 | Duration: 2.78 secs | Value: 2.191852e+01
# Epoch:  50/200 | Duration: 3.75 secs | Value: 1.834452e+01
# Epoch:  51/200 | Duration: 2.69 secs | Value: 2.240622e+01
# Epoch:  52/200 | Duration: 2.47 secs | Value: 2.087134e+01
# Epoch:  53/200 | Duration: 2.82 secs | Value: 2.169718e+01
# Epoch:  54/200 | Duration: 2.87 secs | Value: 2.258390e+01
# Epoch:  55/200 | Duration: 2.48 secs | Value: 2.224915e+01
# Epoch:  56/200 | Duration: 2.81 secs | Value: 2.195983e+01
# Epoch:  57/200 | Duration: 4.21 secs | Value: 2.183775e+01
# Epoch:  58/200 | Duration: 2.84 secs | Value: 2.299410e+01
# Epoch:  59/200 | Duration: 2.99 secs | Value: 2.197595e+01
# Epoch:  60/200 | Duration: 2.96 secs | Value: 2.270632e+01
# Epoch:  61/200 | Duration: 2.61 secs | Value: 2.210921e+01
# Epoch:  62/200 | Duration: 3.42 secs | Value: 2.280445e+01
# Epoch:  63/200 | Duration: 2.91 secs | Value: 2.272784e+01
# Epoch:  64/200 | Duration: 2.63 secs | Value: 2.291541e+01
# Epoch:  65/200 | Duration: 2.81 secs | Value: 2.267975e+01
# Epoch:  66/200 | Duration: 4.44 secs | Value: 2.283616e+01
# Epoch:  67/200 | Duration: 2.58 secs | Value: 2.319896e+01
# Epoch:  68/200 | Duration: 2.76 secs | Value: 2.288948e+01
# Epoch:  69/200 | Duration: 3.04 secs | Value: 2.306199e+01
# Epoch:  70/200 | Duration: 2.61 secs | Value: 2.303702e+01
# Epoch:  71/200 | Duration: 2.84 secs | Value: 2.328264e+01
# Epoch:  72/200 | Duration: 3.05 secs | Value: 2.320930e+01
# Epoch:  73/200 | Duration: 3.21 secs | Value: 2.318500e+01
# Epoch:  74/200 | Duration: 2.81 secs | Value: 2.335529e+01
# Epoch:  75/200 | Duration: 2.84 secs | Value: 2.340682e+01
# Epoch:  76/200 | Duration: 2.95 secs | Value: 2.340404e+01
# Epoch:  77/200 | Duration: 2.94 secs | Value: 2.339556e+01
# Epoch:  78/200 | Duration: 3.04 secs | Value: 2.360778e+01
# Epoch:  79/200 | Duration: 3.37 secs | Value: 2.352621e+01
# Epoch:  80/200 | Duration: 2.75 secs | Value: 2.359881e+01
# Epoch:  81/200 | Duration: 2.43 secs | Value: 2.369052e+01
# Epoch:  82/200 | Duration: 3.32 secs | Value: 2.372236e+01
# Epoch:  83/200 | Duration: 3.54 secs | Value: 2.377732e+01
# Epoch:  84/200 | Duration: 2.66 secs | Value: 2.381655e+01
# Epoch:  85/200 | Duration: 2.40 secs | Value: 2.394507e+01
# Epoch:  86/200 | Duration: 3.09 secs | Value: 2.392381e+01
# Epoch:  87/200 | Duration: 2.69 secs | Value: 2.405816e+01
# Epoch:  88/200 | Duration: 2.66 secs | Value: 2.411647e+01
# Epoch:  89/200 | Duration: 2.44 secs | Value: 2.418195e+01
# Epoch:  90/200 | Duration: 2.68 secs | Value: 2.426179e+01
# Epoch:  91/200 | Duration: 2.30 secs | Value: 2.438193e+01
# Epoch:  92/200 | Duration: 2.28 secs | Value: 2.442755e+01
# Epoch:  93/200 | Duration: 2.24 secs | Value: 2.453532e+01
# Epoch:  94/200 | Duration: 2.46 secs | Value: 2.465955e+01
# Epoch:  95/200 | Duration: 2.35 secs | Value: 2.475421e+01
# Epoch:  96/200 | Duration: 2.34 secs | Value: 2.486911e+01
# Epoch:  97/200 | Duration: 2.49 secs | Value: 2.499295e+01
# Epoch:  98/200 | Duration: 2.34 secs | Value: 2.510846e+01
# Epoch:  99/200 | Duration: 2.58 secs | Value: 2.521220e+01
# Epoch: 100/200 | Duration: 3.10 secs | Value: 2.526949e+01
# Epoch: 101/200 | Duration: 2.37 secs | Value: 2.520489e+01
# Epoch: 102/200 | Duration: 2.39 secs | Value: 2.443970e+01
# Epoch: 103/200 | Duration: 2.73 secs | Value: 2.441628e+01
# Epoch: 104/200 | Duration: 2.60 secs | Value: 2.475938e+01
# Epoch: 105/200 | Duration: 2.48 secs | Value: 2.558550e+01
# Epoch: 106/200 | Duration: 2.71 secs | Value: 2.457510e+01
# Epoch: 107/200 | Duration: 2.70 secs | Value: 2.336762e+01
# Epoch: 108/200 | Duration: 3.66 secs | Value: 2.592044e+01
# Epoch: 109/200 | Duration: 2.39 secs | Value: 2.400915e+01
# Epoch: 110/200 | Duration: 2.60 secs | Value: 2.419095e+01
# Epoch: 111/200 | Duration: 3.95 secs | Value: 2.523286e+01
# Epoch: 112/200 | Duration: 3.38 secs | Value: 2.444301e+01
# Epoch: 113/200 | Duration: 3.66 secs | Value: 2.564689e+01
# Epoch: 114/200 | Duration: 3.14 secs | Value: 2.484986e+01
# Epoch: 115/200 | Duration: 3.80 secs | Value: 2.578136e+01
# Epoch: 116/200 | Duration: 2.64 secs | Value: 2.480752e+01
# Epoch: 117/200 | Duration: 2.57 secs | Value: 2.606980e+01
# Epoch: 118/200 | Duration: 2.25 secs | Value: 2.534570e+01
# Epoch: 119/200 | Duration: 2.27 secs | Value: 2.578517e+01
# Epoch: 120/200 | Duration: 2.97 secs | Value: 2.590338e+01
# Epoch: 121/200 | Duration: 2.49 secs | Value: 2.575971e+01
# Epoch: 122/200 | Duration: 2.30 secs | Value: 2.608520e+01
# Epoch: 123/200 | Duration: 2.33 secs | Value: 2.583211e+01
# Epoch: 124/200 | Duration: 2.28 secs | Value: 2.632285e+01
# Epoch: 125/200 | Duration: 2.36 secs | Value: 2.593463e+01
# Epoch: 126/200 | Duration: 2.65 secs | Value: 2.637913e+01
# Epoch: 127/200 | Duration: 2.38 secs | Value: 2.615958e+01
# Epoch: 128/200 | Duration: 2.25 secs | Value: 2.634647e+01
# Epoch: 129/200 | Duration: 2.37 secs | Value: 2.641267e+01
# Epoch: 130/200 | Duration: 4.13 secs | Value: 2.632967e+01
# Epoch: 131/200 | Duration: 4.19 secs | Value: 2.660811e+01
# Epoch: 132/200 | Duration: 5.07 secs | Value: 2.641059e+01
# Epoch: 133/200 | Duration: 3.58 secs | Value: 2.669693e+01
# Epoch: 134/200 | Duration: 3.93 secs | Value: 2.655805e+01
# Epoch: 135/200 | Duration: 4.03 secs | Value: 2.674044e+01
# Epoch: 136/200 | Duration: 2.66 secs | Value: 2.671542e+01
# Epoch: 137/200 | Duration: 2.34 secs | Value: 2.680203e+01
# Epoch: 138/200 | Duration: 2.44 secs | Value: 2.685273e+01
# Epoch: 139/200 | Duration: 2.38 secs | Value: 2.687118e+01
# Epoch: 140/200 | Duration: 2.38 secs | Value: 2.697922e+01
# Epoch: 141/200 | Duration: 3.22 secs | Value: 2.696878e+01
# Epoch: 142/200 | Duration: 2.35 secs | Value: 2.707256e+01
# Epoch: 143/200 | Duration: 4.63 secs | Value: 2.708180e+01
# Epoch: 144/200 | Duration: 5.89 secs | Value: 2.716030e+01
# Epoch: 145/200 | Duration: 5.82 secs | Value: 2.719769e+01
# Epoch: 146/200 | Duration: 6.40 secs | Value: 2.722285e+01
# Epoch: 147/200 | Duration: 6.53 secs | Value: 2.732597e+01
# Epoch: 148/200 | Duration: 6.62 secs | Value: 2.730808e+01
# Epoch: 149/200 | Duration: 6.06 secs | Value: 2.739718e+01
# Epoch: 150/200 | Duration: 6.19 secs | Value: 2.742774e+01
# Epoch: 151/200 | Duration: 3.96 secs | Value: 2.740640e+01
# Epoch: 152/200 | Duration: 4.23 secs | Value: 2.747256e+01
# Epoch: 153/200 | Duration: 5.61 secs | Value: 2.754060e+01
# Epoch: 154/200 | Duration: 4.16 secs | Value: 2.757196e+01
# Epoch: 155/200 | Duration: 2.40 secs | Value: 2.757683e+01
# Epoch: 156/200 | Duration: 2.50 secs | Value: 2.756177e+01
# Epoch: 157/200 | Duration: 2.16 secs | Value: 2.757827e+01
# Epoch: 158/200 | Duration: 2.18 secs | Value: 2.759295e+01
# Epoch: 159/200 | Duration: 2.42 secs | Value: 2.770541e+01
# Epoch: 160/200 | Duration: 2.71 secs | Value: 2.779476e+01
# Epoch: 161/200 | Duration: 5.77 secs | Value: 2.779180e+01
# Epoch: 162/200 | Duration: 5.00 secs | Value: 2.781508e+01
# Epoch: 163/200 | Duration: 3.93 secs | Value: 2.789053e+01
# Epoch: 164/200 | Duration: 2.46 secs | Value: 2.791907e+01
# Epoch: 165/200 | Duration: 2.61 secs | Value: 2.794466e+01
# Epoch: 166/200 | Duration: 4.90 secs | Value: 2.800007e+01
# Epoch: 167/200 | Duration: 3.18 secs | Value: 2.803196e+01
# Epoch: 168/200 | Duration: 3.30 secs | Value: 2.806307e+01
# Epoch: 169/200 | Duration: 3.21 secs | Value: 2.810720e+01
# Epoch: 170/200 | Duration: 3.29 secs | Value: 2.814934e+01
# Epoch: 171/200 | Duration: 2.69 secs | Value: 2.817044e+01
# Epoch: 172/200 | Duration: 2.47 secs | Value: 2.822318e+01
# Epoch: 173/200 | Duration: 2.28 secs | Value: 2.826623e+01
# Epoch: 174/200 | Duration: 2.58 secs | Value: 2.829550e+01
# Epoch: 175/200 | Duration: 3.17 secs | Value: 2.833215e+01
# Epoch: 176/200 | Duration: 2.40 secs | Value: 2.837964e+01
# Epoch: 177/200 | Duration: 2.42 secs | Value: 2.842357e+01
# Epoch: 178/200 | Duration: 2.27 secs | Value: 2.845175e+01
# Epoch: 179/200 | Duration: 2.71 secs | Value: 2.848457e+01
# Epoch: 180/200 | Duration: 5.06 secs | Value: 2.852299e+01
# Epoch: 181/200 | Duration: 6.25 secs | Value: 2.856810e+01
# Epoch: 182/200 | Duration: 10.56 secs | Value: 2.861128e+01
# Epoch: 183/200 | Duration: 10.13 secs | Value: 2.865015e+01
# Epoch: 184/200 | Duration: 10.48 secs | Value: 2.868794e+01
# Epoch: 185/200 | Duration: 2.94 secs | Value: 2.872227e+01
# Epoch: 186/200 | Duration: 2.88 secs | Value: 2.874967e+01
# Epoch: 187/200 | Duration: 2.88 secs | Value: 2.874595e+01
# Epoch: 188/200 | Duration: 3.22 secs | Value: 2.861473e+01
# Epoch: 189/200 | Duration: 3.52 secs | Value: 2.776503e+01
# Epoch: 190/200 | Duration: 2.95 secs | Value: 2.783743e+01
# Epoch: 191/200 | Duration: 3.78 secs | Value: 2.821163e+01
# Epoch: 192/200 | Duration: 3.78 secs | Value: 2.753316e+01
# Epoch: 193/200 | Duration: 2.87 secs | Value: 2.509913e+01
# Epoch: 194/200 | Duration: 2.61 secs | Value: 1.284011e+01
# Epoch: 195/200 | Duration: 2.78 secs | Value: 2.314720e+01
# Epoch: 196/200 | Duration: 3.22 secs | Value: 1.141620e+01
# Epoch: 197/200 | Duration: 9.53 secs | Value: 8.950174e+00
# Epoch: 198/200 | Duration: 9.52 secs | Value: 2.136587e+01
# Epoch: 199/200 | Duration: 9.65 secs | Value: 1.028712e+01
# Epoch: 200/200 | Duration: 3.93 secs | Value: 8.342092e+00
# [[-0.1261 -0.1232 -0.0992 -0.0789 -0.1008 -0.0791]
#  [-0.1190 -0.1231 -0.0906 -0.0935 -0.0749 -0.0707]
#  [-0.1060 -0.0992 -0.0913 -0.1029 -0.0956 -0.0850]
#  [-0.1022 -0.0988 -0.0955 -0.0943 -0.0942 -0.0944]
#  [-0.1145 -0.1013 -0.0920 -0.0981 -0.0988 -0.0947]
#  [-0.0980 -0.0965 -0.0979 -0.0992 -0.1047 -0.1264]]

# %%
obj = []
mpl.rcParams.update({'font.size': 20})
for i in range(490, 500):
    Ex = np.loadtxt('bent_tm/Ex_%03d.csv' % i, delimiter=',')
    epsr = np.loadtxt('bent_tm/epsr_%03d.csv' % i, delimiter=',')
#     if i == 1:
#         normal = mode_overlap(Ex, ground)
#     obj.append(mode_overlap(Ex, ground) / normal)
    
    fig, axs = plt.subplots(1, 2, constrained_layout=True, figsize=(8,4))
    epsr_graph = np.array(epsr, copy=True)
    epsr_graph[Npml+space:Nx-Npml-space, Npml+space:Ny-Npml-space] = 0
    
    for ax in axs:
        ax.set_xlabel('')
        ax.set_ylabel('')
        ax.set_yticks([])
        ax.set_xticks([])
#     for ax in axs[1][0:2]:
#         ax.set_xlabel('Epoch')
#         ax.set_ylabel('Percent Change in Objective')
    
    abslt(Ex, outline=epsr_graph, ax=axs[0], cbar=True, vmax=5e-8)
#     axs[1][0].plot(obj)
    real(epsr, ax=axs[1], cmap='RdGy', cbar=True, vmin=-6, vmax=1)
#     axs[-1][-1].axis('off')
    plt.savefig('bent_tm/normalized_%03d.png' % i, dpi=70)
    plt.close()

# %%
make_gif('bent_tm.gif', 500, 'bent_tm')
